# %% [markdown]
# Data Structure : Data Structure is the efficient way of storing the daata or storing the data in an Organized way
#
#
# Different types of  Data Structures:
#
# *   Arrays
# *   Linked List
# *   Queues
# *   Stacks
# *   Trees
#
#
# Different types of Data Structures in Python
#
# *   List
# *   Tuple
# *   Set
# *   Dictionary
#
#
#
# *   List : Lists are used to store multiple items of different Data Types.
# *   List item
#
#
#
#
#
#
#
#
#
# Algorithims :It is Logic Building.Sequence of Steps to solve any problems.
#
# Diffferent Types of Algorithms:
#
# *   Greedy Algorithim
# *   Divide and Conquer
# *   Dynamic Programming

# %%
list1=[1,2,"Priya","Bhatia",23,"CV"]
type(list1)
# Out:
# list

# %%
list1
# Out:
# [1, 2, 'Priya', 'Bhatia', 23, 'CV']

# %% [markdown]
# Accessing List elements is called as Random Access Property
#
# This property of random Access is used in Binary Search

# %%
list1[2]
# Out:
# 'Priya'

# %% [markdown]
# Properties of List in Python
# ============================
# 1.Dynamic List : this will internally create a space.Whenever a List is created.. A duplicate List is created with double the space. Hence "out of Bound" exception is not seen in Python.
#
# 2. List is Mutuable : The Original list elements can be modified.
#
# Elemnts can be Added or Removed from the List
#
# Real Life Example of Lists : dataset as a csv files which are used in Machine Learning are stored as Lists.Huge amount of Data is stored in Lists

# %% [markdown]
# **Tuples**
#
# Properties of a Tuple
#
#
# *   () - These brackets are used to represent a Tuple
# *   Tuples are Immutable..hence they only have two properties for operation   count() and index()
#
# *   Tuples operation is faster than Lists Operation because of its Immutable property. Henc ewhen a Tuple is created it is fixed..No further addition of memeory is done as its done in Lists because of "Dynamic Lists"Property
# *   List item

# %%
tuple1=(2,5,7,9,10)
type(tuple1)
# Out:
# tuple

# %%
tuple1
# Out:
# (2, 5, 7, 9, 10)

# %% [markdown]
# **Conditions to choose the Data Stuctures - Tuple**
#
# 1.   Choose Tuple ,when there is no changes required to be done to a Data Structure
# 2.   Choose Tuple when you need a faster Operation and no data modification is required
#
#
#
# **Conditions to choose the Data Stuctures - List**
#
# 1.   Choose List ,when there change is required to be done to a Data Structure
# 2.   Operating time is not the criteria then choose List

# %% [markdown]
# **Set{}**
#
# 1.   if set is empty with curly braces as set1={} - then type(set1) is seen as dict
# 2.  if set has elements with the curly braces as set1={1,2,3,4,5} - then type(set1) is seen as set ..This is because the way the elements are inserted in the set.
# 3.   Elements from the set() cannot be accessed using the index value.Since the elements inside the set90 is not in a Ordered Fashion. Hence set1[0]=>gives an Error
# 4.   Sets() does not allowDuplicates...This is reason for the Usage of Sets

# %%
set1={}
type(set1)
# Out:
# dict

# %%
set1={10,20,3,4}
type(set1)
# Out:
# set

# %% [markdown]
# Removing of duplicate element from a List using set()

# %%
list1=[2,3,4,2,7]
set2=set(list1)

# %%
set2
# Out:
# {2, 3, 4, 7}

# %%
list(set2)
# Out:
# [2, 3, 4, 7]

# %%
set2.add(20)

# %%
set2
# Out:
# {2, 3, 4, 7, 20}

# %%
set2.clear() ##All the elements from the set2 are cleared

# %%
set2
# Out:
# set()

# %% [markdown]
# Elemnts in the set cannot be accessed using the index value.As elements inside set are unOrdered

# %%
set1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2166654704.py in <cell line: 0>()
# ----> 1 set1[0]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# **Dictionary**
#
# 1.   Dictionary uses the key-value pair.
#      keys - Donot allow "Duplicate" values
# 2.   Dictionary also is represnted by {} brackets
#
#  "Hashing" is the  common Data Structure that is used internally to create
#  set{} and Dictionary {key:value}
#
# Hashing: Hashing is a Data Structure where we obeserve that its Lookup time/Search time is constant ie O(1)
#
# 3.   In Dictionary "key" is the Index Number.hence to access the Dictionary elements "key" is used
#
# 4.   Dictionary is Mutable
#
# 5.   JSON files are of type Dictionary

# %%
dict1={}
type(dict1)
# Out:
# dict

# %%
dict1={}

# %%
dict1={"name":"ansh","emailID":"ansh@gmail.com","contact":8965854214}

# %%
dict1
# Out:
# {'name': 'ansh', 'emailID': 'ansh@gmail.com', 'contact': 8965854214}

# %%
dict1
# Out:
# {'name': 'ansh', 'emailID': 'ansh@gmail.com', 'contact': 8965854214}

# %%
dict1["name"]
# Out:
# 'ansh'

# %%
dict1["emailID"]
# Out:
# 'ansh@gmail.com'

# %%
dict1["contact"]
# Out:
# 8965854214

# %%
## Adding a New key: value pair to the existing dictionary
dict1["address"] ="abc colony"

# %%
dict1
# Out:
# {'name': 'ansh',
#  'emailID': 'ansh@gmail.com',
#  'contact': 8965854214,
#  'address': 'abc colony'}

# %% [markdown]
# **String is also a Data Structure in Python**
