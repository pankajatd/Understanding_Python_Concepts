# %%
#Iniialization of a string
str1="Priya"

# %%
type(str1)
# Out:
# str

# %%
#Accessing elements of the string..Forward direction
str1[3]
# Out:
# 'y'

# %%
#Accessing elements of the string..Backrward direction
str1[-5]
# Out:
# 'P'

# %%
#Length_of_the string
len(str1)

# %%
#Inbuilt functions of the string
str1.find('j') #This funtion returns the index of the eleemnt 'j' in the string

# %%
##find is similar to searchin a binary return.>if found the search returns 1 ..else it returns -1.Similary here its returning -1
str1.find('z')#Since this element 'z' is not present ..it returns  -1 ..by default.

# %%
#Split function in Python
##In realtimne application the function split() is used in NLP(Textual Data)
##Sentiment Analysis.
text1=" Hello Priya" #split function the string into individual tokens and returns it as a list
text1.split()

# %%
##Replace the word 'priya by "world"
text1.replace('Priya','Python')#replace function does not do the reassignment of the word hence the original string does not change.

# %%
text1

# %%
# to do the changes to the original string reassignment needs to be done
text1=text1.replace ('Priya','World')

# %%
text1

# %%
##Count().Counts the gven character.It counts the frequency of the given character
##How many times character is appearin gin the below function.
str2='Priya Bhatia'
str2.count('a')
# Out:
# 3

# %%
str2.count('z')
# Out:
# 0

# %%
str2.count('-b') #Input string contain the word "Bhatia " where 'B' is caps and
                 #since Python is case sensitive ...this is treated as different.Hence it returns 0
# Out:
# 0

# %%
str2.count('B')
# Out:
# 1

# %%
#Conversion to Lowercasse character
str2.lower() #All the characters are converted to Lowercase
# Out:
# 'priya bhatia'

# %%
str2.upper()#All the characters are converted to Uppercase
# Out:
# 'PRIYA BHATIA'

# %%
##Swap case.Lower case is converted to Upper and Upper case is converted to Lower
str2.swapcase()
# Out:
# 'pRIYA bHATIA'

# %%
##title() and capitalize()..Difference between captitalize() and title() functions
#title() -this function converts first letter of every word in string to a capital letter
str3="this is the  mastering python strings master class hosted by priya bhatia"
str3.title()
# Out:
# 'This Is The  Mastering Python Strings Master Class Hosted By Priya Bhatia'

# %%
#title() -this function converts only the first letter of the enitre string to a capital letter
str3.capitalize()
# Out:
# 'This is the  mastering python strings master class hosted by priya bhatia'

# %%
##STRING SLICING
#for  slicing its always  str1[0:last_index+1]
##getting the first 3 characters of the string

str1[0:3]
# Out:
# 'Pri'

# %%
#To get the alternate characters from the string str1
#str1[0:5:2] #Thlast index 2 is the Number of steps you want to Jump
#or can be written as
str1[0::2] ##here 2 indicates the number of steps you want to jump
# Out:
# 'Pia'

# %%
#To get the alternate characters from the string str1
str1[0:5:2] #Thlast index 2 is the Number of steps you want to Jump
# Out:
# 'Pia'

# %%
#To get the alternate characters from the string str1
str1[::2] #Thlast index 2 is the Number of steps you want to Jump
# Out:
# 'Pia'

# %%
#To reverse the entire string
str1[4::-1] #The last index -1 is because you want to get it till 0
# Out:
# 'ayirP'

# %%
#To reverse the entire string,instead of mentioning the start index
str1[::-1] #The last index -1 is because you want to get it till 0
# Out:
# 'ayirP'

# %%
#To get 'riya'from the string
str1[1:5:1]
# Out:
# 'riya'

# %%
#To get 'ayir'from the string ,which is the reverse
str1[4:0:-1]
# Out:
# 'ayir'

# %%
#To get 'ayi'from the string
str1[4:1:-1]
# Out:
# 'ayi'

# %%
#To get 'ayi'from the string,using Negative Indexing
str1[:1:-1]
# Out:
# 'ayi'
